# %% [markdown]
# # Credit Risk Prediction System

# %% [markdown]
# ## Part A: Data acquisition and understanding

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("credit_risk_dataset.csv")

#Displaying shape
print("Dataset shape [rows, columns]:", df.shape)
# Out:
# Dataset shape [rows, columns]: (32581, 12)

# %%
#Displaying columns
print("Columns:")
print(df.columns.tolist())
# Out:
# Columns:
# ['person_age', 'person_income', 'person_home_ownership', 'person_emp_length', 'loan_intent', 'loan_grade', 'loan_amnt', 'loan_int_rate', 'loan_status', 'loan_percent_income', 'cb_person_default_on_file', 'cb_person_cred_hist_length']

# %%
#Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32581 entries, 0 to 32580
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  32581 non-null  int64
#  1   person_income               32581 non-null  int64
#  2   person_home_ownership       32581 non-null  object
#  3   person_emp_length           31686 non-null  float64
#  4   loan_intent                 32581 non-null  object
#  5   loan_grade                  32581 non-null  object
#  6   loan_amnt                   32581 non-null  int64
#  7   loan_int_rate               29465 non-null  float64
#  8   loan_status                 32581 non-null  int64
#  9   loan_percent_income         32581 non-null  float64
#  10  cb_person_default_on_file   32581 non-null  object
#  11  cb_person_cred_hist_length  32581 non-null  int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 3.0+ MB

# %%
#describe
df.describe()
# Out:
#          person_age  person_income  person_emp_length     loan_amnt  \
# count  32581.000000   3.258100e+04       31686.000000  32581.000000
# mean      27.734600   6.607485e+04           4.789686   9589.371106
# std        6.348078   6.198312e+04           4.142630   6322.086646
# min       20.000000   4.000000e+03           0.000000    500.000000
# 25%       23.000000   3.850000e+04           2.000000   5000.000000
# 50%       26.000000   5.500000e+04           4.000000   8000.000000
# 75%       30.000000   7.920000e+04           7.000000  12200.000000
# max      144.000000   6.000000e+06         123.000000  35000.000000
#
#        loan_int_rate   loan_status  loan_percent_income  \
# count   29465.000000  32581.000000         32581.000000
# mean       11.011695      0.218164             0.170203
# std         3.240459      0.413006             0.106782
# min         5.420000      0.000000             0.000000
# 25%         7.900000      0.000000             0.090000
# 50%        10.990000      0.000000             0.150000
# 75%        13.470000      0.000000             0.230000
# max        23.220000      1.000000             0.830000
#
#        cb_person_cred_hist_length
# count                32581.000000
# mean                     5.804211
# std                      4.055001
# min                      2.000000
# 25%                      3.000000
# 50%                      4.000000
# 75%                      8.000000
# max                     30.000000

# %%
#Identifying missing values
missing = df.isnull().sum()
missing_percent = (missing / len(df)) * 100
missing_summary = pd.DataFrame({'missing_count': missing, 'missing_percent': missing_percent})
missing_summary = missing_summary[missing_summary['missing_count'] > 0].sort_values('missing_count', ascending=False)
print("Columns with missing values:")
missing_summary
# Out:
# Columns with missing values:
#                    missing_count  missing_percent
# loan_int_rate               3116         9.563856
# person_emp_length            895         2.747000

# %% [markdown]
# The dataset contains a mix of numeric and categorial features. And two columns `[loan_int_rate and person_emp_length]` contains missing values.

# %% [markdown]
# ## PART B: Exploratory Data Analysis (EDA)

# %%
# !pip install seaborn

#Visualisations
import matplotlib.pyplot as plt #for creating charts/graphs
import seaborn as sns #for higher-level plots

sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (6, 4)
# Out:
# Requirement already satisfied: seaborn in c:\users\lihle\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\lihle\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from seaborn) (2.1.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\lihle\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\lihle\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lihle\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\lihle\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lihle\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lihle\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\lihle\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\lihle\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lihle\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lihle\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lihle\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lihle\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\lihle\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
#Target variable distribution
plt.figure()
axes = sns.countplot(x='loan_status', hue='loan_status', data = df,
                     palette=['lime', 'skyblue'], legend=False)
plt.title('Distribution of Target Variable: Loan Status')
plt.xlabel('Loan Status (0 = Low Risk / Repaid, 1 = High Risk / Default)') #X-axis label
plt.ylabel('Count') #y-axis label

for p in axes.patches:
    axes.annotate(f'{int(p.get_height())}', (p.get_x()+p.get_width()/2, p.get_height()),
                  ha='center', va='bottom') #horizontally centering the text and positioning text above the bar top
plt.tight_layout()
#Saving the chart as a png 
plt.savefig('01_target_distribution.png', dpi=110)
plt.show()

#Intepretation:
#The target classes are imbalanced (78% low-risk vs 22% high-risk).
#A naive model could reach 78% accuracy by just predicting the majority
# class, so techniques like class weighing and metric like
#precision/recal/F1 should be considered when modelling.

# %%
#Correlation heatmap
plt.figure(figsize=(9, 7))
numeric_df = df.select_dtypes(include=[np.number])
corr = numeric_df.corr()
sns.heatmap(corr, annot=True, fmt='.2f',cmap='RdYlBu', center=0)
plt.title('Correlation Heatmap of Numeric Features')
plt.tight_layout()
plt.savefig('02_correlation_heatmap.png', dpi=110)
plt.show()
